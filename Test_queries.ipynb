# %% [markdown]
# Import Libraries and Load Config

# %%
import psycopg2
import pandas as pd
import configparser

# %% [markdown]
# Load Redshift Config from dwh.cfg

# %%
# Load config
config = configparser.ConfigParser()
config.read('dwh.cfg')

# Set connection parameters
HOST = config.get('CLUSTER', 'HOST')
DB_NAME = config.get('CLUSTER', 'DB_NAME')
DB_USER = config.get('CLUSTER', 'DB_USER')
DB_PASSWORD = config.get('CLUSTER', 'DB_PASSWORD')
DB_PORT = config.get('CLUSTER', 'DB_PORT')

# %% [markdown]
# Connect to Redshift

# %%
# Connect to Redshift
conn = psycopg2.connect(
    host=HOST,
    dbname=DB_NAME,
    user=DB_USER,
    password=DB_PASSWORD,
    port=DB_PORT
)
cur = conn.cursor()

# %% [markdown]
# Query Helper Function

# %%
# Helper function to run a query and return a DataFrame
def run_query(query):
    cur.execute(query)
    df = pd.DataFrame(cur.fetchall(), columns=[desc[0] for desc in cur.description])
    return df

# %% [markdown]
# Check staging table counts

# %%
run_query("""
SELECT 'staging_events' AS table_name, COUNT(*) AS row_count FROM staging_events
UNION ALL
SELECT 'staging_songs', COUNT(*) FROM staging_songs;
""")
# Out:
#        table_name  row_count
# 0  staging_events       8056
# 1   staging_songs         82

# %% [markdown]
# Check dimension/fact tables

# %%
run_query("""
SELECT 'users' AS table_name, COUNT(*) FROM users
UNION ALL
SELECT 'songs', COUNT(*) FROM songs
UNION ALL
SELECT 'artists', COUNT(*) FROM artists
UNION ALL
SELECT 'time', COUNT(*) FROM time
UNION ALL
SELECT 'songplays', COUNT(*) FROM songplays;
""")
# Out:
#   table_name  count
# 0      users    105
# 1      songs     71
# 2    artists     69
# 3       time   6813
# 4  songplays   6820

# %% [markdown]
# Sample songplays

# %%
run_query("SELECT * FROM songplays LIMIT 5;")
# Out:
#    songplay_id          start_time  user_id level song_id artist_id  \
# 0            0 2018-11-01 21:05:52        8  free    None      None
# 1            6 2018-11-01 21:42:00       10  free    None      None
# 2            8 2018-11-01 21:52:05       26  free    None      None
# 3           12 2018-11-01 22:23:14      101  free    None      None
# 4           14 2018-11-03 01:05:50       53  free    None      None
#
#    session_id                                      location  \
# 0         139                   Phoenix-Mesa-Scottsdale, AZ
# 1           9  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 2         169            San Jose-Sunnyvale-Santa Clara, CA
# 3         100                      New Orleans-Metairie, LA
# 4          52                             Klamath Falls, OR
#
#                                           user_agent
# 0  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 1  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 2  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 3  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 4  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...

# %% [markdown]
# Most active users

# %%
run_query("""
SELECT user_id, COUNT(*) AS total_plays
FROM songplays
GROUP BY user_id
ORDER BY total_plays DESC
LIMIT 5;
""")
# Out:
#    user_id  total_plays
# 0       49          689
# 1       80          665
# 2       97          557
# 3       15          463
# 4       44          397

# %% [markdown]
# Most played songs

# %%
run_query("""
SELECT s.title, COUNT(*) AS play_count
FROM songplays sp
JOIN songs s ON sp.song_id = s.song_id
GROUP BY s.title
ORDER BY play_count DESC
LIMIT 10;
""")
# Out:
#             title  play_count
# 0  Setanta matins           1

# %% [markdown]
# Plays per day

# %%
run_query("""
SELECT DATE(start_time) AS play_date, COUNT(*) AS total_plays
FROM songplays
GROUP BY play_date
ORDER BY play_date;
""")
# Out:
#      play_date  total_plays
# 0   2018-11-01           11
# 1   2018-11-02          155
# 2   2018-11-03          100
# 3   2018-11-04          144
# 4   2018-11-05          356
# 5   2018-11-06          154
# 6   2018-11-07          174
# 7   2018-11-08          161
# 8   2018-11-09          252
# 9   2018-11-10           87
# 10  2018-11-11           73
# 11  2018-11-12          166
# 12  2018-11-13          339
# 13  2018-11-14          390
# 14  2018-11-15          479
# 15  2018-11-16          319
# 16  2018-11-17          127
# 17  2018-11-18          138
# 18  2018-11-19          276
# 19  2018-11-20          322
# 20  2018-11-21          437
# 21  2018-11-22           82
# 22  2018-11-23          239
# 23  2018-11-24          314
# 24  2018-11-25           41
# 25  2018-11-26          216
# 26  2018-11-27          256
# 27  2018-11-28          363
# 28  2018-11-29          319
# 29  2018-11-30          330
